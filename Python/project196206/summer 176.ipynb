# %%
# ATM system
# libaray Managements system
# School managements system
# hostel management system

# %%
# ATM system

# I will store the data in of users in Dictionaries
# 2nd version I will store data in lists
# 3rd I will store data in sets
# I will create my own datatype in which I will store the data(learn more)

# %% [markdown]
# # ATM project with dictionaries
#
# # data stored
# - Account name
# - unique UID generated for each user (use increament from some some)
# - balance
# - last withdrawal
# - stored in files optional
#
# # functions
# - check balance
# - widthdraw amount
#
#
# # constaints
# - if pin is incorrect enter the user to enter again if wrong 3 times ask the user to reset using his UID
# - if balance is low say low balance try other amount
#
# # additions
# after withdrawal show on the screen Thank you for using this atm
# - count your cast

# %%
accounts = {}
allaccountsno = set({})

# %%
# create user account
def create_account(allacountsno = allaccountsno):
    newUser = []
    name = input("Name: ")
    age = int(input("Age: "))
    account_type = input(r"Current \ Saving ")
    address = input("Address: ")
    branchno = int(input("Branch Number: "))
    balance = 0

    

    # when account created ask user to set ATM PIN
    
    newUser.append(name)
    newUser.append(age)
    newUser.append(account_type)
    newUser.append(address)
    newUser.append(balance)

    # how will be the account No generated first PK10 AKML 1929 0023 1911 3842
    

    # how will I generate the rest 00 + 2 digits + 8 digits but should be uniques
    # acha now isa logic banana hai k jo account numbers generate ho us k jiasa na ho

    # accountsno ={}
    while True:
        import random 
        accno = random.randint(1111111111,9999999999)
        if accno in allaccountsno:
            pass
        else:
            allaccountsno.add(octa)
            IBAN = "PK10"+"AKML"+str(branchno)+ "00"+str(accno)
            break
    
    # creating the account
    accounts[IBAN] = newUser
    print("Account Successfully Created!")

# %%
create_account()
# Out:
# Name:  Anwar
# Age:  23
# Current \ Saving  Saving
# Address:  Parachinar
# Branch Number:  1601
# Account Successfully Created!

# %%
# let me check if me the accounts
print(accounts)
# Out:
# {'PK10AKML1909003563235155': ['Ahmad', 22, 'Saving', 'Latamber karak', 0], 'PK10AKML1909005231832905': ['Zayan', 22, 'Current', 'Karak', 0], 'PK10AKML1601002274502492': ['Anwar', 23, 'Saving', 'Parachinar', 0]}

# %%
# now creating add balance to the system

def add_balance(accounts = accounts):
    # we have to see 2 things is the accounts Number in the accountsno 
    IBAN = input("Enter IBAN: ")
    if IBAN in accounts.keys():
        Balance = int(input("Enter Amount: "))
        accounts[IBAN][4] = Balance
        return f"Successfully Added {Balance} to your account"
    else:
        return "Account no found"

# %%
# now the function of checking balance
def check_balance(accounts = accounts):
    IBAN = input("Enter IBAN : ")
    if IBAN in accounts:
        return f"Balance : {accounts[IBAN][4]}"
    else:
        return f"Account not found"

# %%
# now the last function of withdrawing the money
def withdrawamount(accounts= accounts):
    IBAN = input("Enter IBAN : ")
    if IBAN in accounts:
        amount = int(input("Withdrawal Amount : "))
        accounts[IBAN][4] = accounts[IBAN][4] - amount
        return f"Withdrawal successful remaining amount {accounts[IBAN][4]}"
    else:
        return f"Account Not Found"

# %%
accounts['PK10AKML1909003563235155'][4] - 100
# Out:
# 250

# %%
# lets check how to add balance to dictionaries
# sir wanted me to publish my project on online (Thank you sir Hameeed , and Zakir and Mam salma You guys are the best)

accounts['PK10AKML1909003563235155'][4] = 350
print(accounts)
# Out:
# {'PK10AKML1909003563235155': ['Ahmad', 22, 'Saving', 'Latamber karak', 350], 'PK10AKML1909005231832905': ['Zayan', 22, 'Current', 'Karak', 0], 'PK10AKML1601002274502492': ['Anwar', 23, 'Saving', 'Parachinar', 0]}

# %%
for i in accounts.keys():
    print(f"Deleted {accounts[f"{i}"]}")
    del accounts[i]

# %%
# lets trying generating 8 digits
allaccountsno = set({})
branchno = 1912
while True:
        import random 
        accno = random.randint(1111111111,9999999999)
        if accno in allaccountsno:
            pass
        else:
            allaccountsno.add(octa)
            b
            print(IBAN)
            break
# Out:
# PK10AKML1912001494445759

# %%
# acha now isa logic banana hai k jo account numbers generate ho us k jiasa na ho

accountsno ={
    8058063425,6263239148,3905617836
}
while True:
    import random 
    octa = random.randint(1111111111,9999999999)
    if octa in accountsno:
        pass
    else:
        accountsno.add(octa)
        break
# Out:
# (8058063425, 6263239148, 3905617836, 3905617836)

# %%
# I think tuple would be good
type(accountsno)
# Out:
# tuple

# %%
ok = {23,24,25}
ok.remove(25)

# %%
ok
# Out:
# {23, 24}

# %%
# acha now isa logic banana hai k jo account numbers generate ho us k jiasa na ho

accountsno ={
    4,2,5,9,8
}
while True:
    import random 
    octa = random.randint(1,9)
    iter = 1
    if octa in accountsno:
        print(f"iter {iter} ")
        iter += 1
    else:
        print(f"iter {iter} ")
        accountsno.add(octa)
        break

print(accountsno)
# Out:
# iter 1
# {2, 3, 4, 5, 8, 9}

# %%
# creating main 
if __name__ == "__main__":
    print("_-"* 20 ,"Welcome to AKM Banks","_-"*20)
    print("Select your choice")
    print("1. Create New Account")
    print("2. Check Balance")
    print("3. Add Balance")
    print("4. Withdraw Amount")
    print("5. Cancel")
    
    while True:
        choice = int(input("Selection: "))
        if choice == 1:
            create_account()
        elif choice == 2:
            checkbalance()
        elif choice ==3:
            add_balance()
        elif choice == 4:
            withdrawamount()
        elif choice == 5:
            break
# Out:
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_- Welcome to AKM Banks _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-
# Select your choice
# 1. Create New Account
# 2. Check Balance
# 3. Add Balance
# 4. Withdraw Amount
# 5. Cancel
# Selection:  1
# Name:  Haziq
# Age:  24
# Current \ Saving  Current
# Address:  Gurgurai Karak
# Branch Number:  1904
# Account Successfully Created!
# Selection:  5

# %%
age = str(int(input("Four digits: ")))

assert len(age) == 4
# Out:
# Four digits:  3456

# %%
# Now all the project for the first time the functional version
accounts = {}
AccountAuth = {} # IBAN : PIN

# create user account function
def create_account(accounts = accounts,AccountAuthorization= AccountAuth):
    newUser = []
    name = input("Name: ")
    age = int(input("Age: "))
    account_type = input(r"Current \ Saving ")
    address = input("Address: ")
    branchno = int(input("Branch Number: "))
    balance = 0

    

    # when account created ask user to set ATM PIN
    
    newUser.append(name)
    newUser.append(age)
    newUser.append(account_type)
    newUser.append(address)
    newUser.append(balance)

    # IBAN format "PK10 AKML 1929 0023 1911 3842"
    while True:
        import random 
        accno = random.randint(1111111111,9999999999)
        if accno in accounts.keys():
            pass
        else:
            IBAN = "PK10"+"AKML"+str(branchno)+ "00"+str(accno)
            break
    
    # creating the account
    accounts[IBAN] = newUser
    

    # creating ATM PIN
    PIN = input("Set PIN : ")
    assert len(PIN) == 4

    
    AccountAuth[IBAN] = PIN
    print("Account Successfully Created! ")
    print(f"User Account Details \n {IBAN} {name} {age} {address} {account_type}")
    
# add balance to account function
def add_balance(accounts = accounts,Auth = AccountAuth):
    # we have to see 2 things is the accounts Number in the accountsno 
    IBAN = input("Enter IBAN: ")
    if IBAN in accounts.keys():
        while True:
            PIN = input("Enter Account PIN : ")
            if len(PIN) != 4:
                print("PIN is 4 digits ")
            elif len(PIN) == 4 and PIN == AccountAuth[IBAN]: 
                Balance = int(input("Enter Amount: "))
                accounts[IBAN][4] = Balance
                print(f"Successfully Added {Balance} to your account")
                break
            elif len(PIN) == 4 and PIN != AccountAuth[IBAN]:
                print("Incorrect PIN Enter Again")
    else:
        print("Account no found")

# now the function of checking balance
def check_balance(accounts = accounts):
    IBAN = input("Enter IBAN : ")
    if IBAN in accounts:
        print(f"Balance : {accounts[IBAN][4]}")
    else:
        print(f"Account not found")


# withdraw amount function
def withdraw_amount(accounts= accounts,Auth = AccountAuth):
    IBAN = input("Enter IBAN : ")
    if IBAN in accounts:
        PIN = input("Enter Account PIN: ")
        while True:
            if len(PIN) != 4:
                print("PIN is 4 digits")
            elif len(PIN) ==4 and PIN ==  AccountAuth[IBAN]:
                amount = int(input("Withdrawal Amount : "))
                accounts[IBAN][4] = accounts[IBAN][4] - amount
                print(f"Withdrawal successful remaining amount {accounts[IBAN][4]}")
                break
            elif len(PIN) == 4 and PIN != AccountAuth[IBAN]:
                print("Incorrect PIN")
    else:
        print(f"Account Not Found")
 
# creating main 
if __name__ == "__main__":
    
    while True:
        print("_-"* 20 ,"Welcome to AKM Banks","_-"*20)
        print("Select your choice")
        print("1. Create New Account")
        print("2. Check Balance")
        print("3. Add Balance")
        print("4. Withdraw Amount")
        print("5. Cancel")
        print("_-"* 25 ,"-_"*25)
        choice = int(input("Selection: "))
        if choice == 1:
            create_account()
        elif choice == 2:
            check_balance()
        elif choice ==3:
            add_balance()
        elif choice == 4:
            withdraw_amount()
        elif choice == 5:
            break
# Out:
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_- Welcome to AKM Banks _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-
# Select your choice
# 1. Create New Account
# 2. Check Balance
# 3. Add Balance
# 4. Withdraw Amount
# 5. Cancel
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_- -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Selection:  1
# Name:  Ahmad
# Age:  22
# Current \ Saving  Saving
# Address:  Karak
# Branch Number:  1889
# Set PIN :  3232
# Account Successfully Created!
# User Account Details
#  PK10AKML1889007187291086 Ahmad 22 Karak Saving
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_- Welcome to AKM Banks _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-
# Select your choice
# 1. Create New Account
# 2. Check Balance
# 3. Add Balance
# 4. Withdraw Amount
# 5. Cancel
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_- -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Selection:  5
