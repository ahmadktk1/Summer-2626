# %%
# working with lambda function

li = ["ahmad","faraz","ali"]

# filtering name if they start with a

for ind in li:
    if ind[-1].lower() =="d":
        print(ind)

# re = filter((lambda a: a[0] == "a"),li)
# print(type(re))

# %%
import datetime

# %%
dir(datetime.datetime)

# %%
now = datetime.datetime.now().date().strftime("%d-%m-20%y")
print(now)

# %%
date = input("Expected Time (%dd-%mm-%yyyy)")

# %%
today = datetime.datetime.today()

# %%
today

# %%
import json
import datetime


def addTask(unfinished):
    taskDescription = input("Task Description : ")
    expectedCompletion = input("Expected Completion Time (%yyyy-%mm-%dd)")
    taskAddedTime = datetime.datetime.now().strftime("%H:%M")

    date = str(datetime.datetime.now().date())
    if str(date) in unfinished.keys():
        next = len(unfinished[date].keys())

        unfinished[date][next + 1]= {
            "task":taskDescription,
            "taskAdded":taskAddedTime,
            "expectedCompletion":expectedCompletion}

        print(f"Successfully Added new Task Time Added {taskAddedTime} Expected Completion Time {expectedCompletion}")

    else:
        print("here 3")
        unfinished[date] = {1:{
                "task":taskDescription,
                "taskAdded":taskAddedTime,
                "expectedCompletion":expectedCompletion
        }

        }
         
        print(f"Successfully Added new Task Time Added {taskAddedTime} Expected Completion Time {expectedCompletion}")

# %%
unfinished = {}

# %%
addTask(unfinished)
print(unfinished)

# %%
for i in p.keys():
    # print(p[i])
    for j in p[i].keys():
        for k in p[i][j].keys():
            print(p[i][j][k])

# %%
unfinished

# %%
date = str(datetime.datetime.now().date())
print(date)
print("here 1 ")

if date in unfinished.keys():
    next = len(unfinished[date].keys())

    unfinished[date][next + 1]= {
        "task":taskDescription,
        "taskAdded":taskAddedTime,
        "expectedCompletion":expectedCompletion}

    print(f"Successfully Added new Task Time Added {taskAddedTime} Expected Completion Time {expectedCompletion}")
else:
    print("not in dict")

# %%
c = datetime.datetime.now()
print(c)

# %%
def showUnfinishedTasks(unfinished):
    print("1. Tadays")
    print("2. ALL")

    choice = int(input("Choice : "))

    if choice == 1:
        today = str(datetime.datetime.now().date())
        if len(unfinished[today]) > 0:
            for key in unfinished[today].keys():
                c = 1
                print(f"{c}   {unfinished[today][key]['task']}   {unfinished[today][key]['expectedCompletion']}")
                c += 1
        else:
            print("No tasks for today")
    
    elif choice == 2:
        totalLength = 0
        for day in unfinished.key():
            totalLength += len(unfinished[day])
            if len(unfinished[day]) > 0:
                for key in unfinished[day].keys():
                    c = 1
                    print(f"{c} {unfinished[day][key]['task']}   {unfinished[day][key]['expectedCompletion']}")
                    c += 1

        
        if totalLength == 0:
            print("No Unfinished Tasks")
    else:
        print("invalid Choice")

# %%
def markTask(finished,unfinished):
    showUnfinishedTasks()
    print("1. Mark Todays Task Complete")
    print("2. Enter Day Task Date : ")

    choice = int(input("Choice 1-2 : "))

    completion = datetime.datetime.now().strftime("%yy-%m-%d, %H:%M")
    if choice == 1:
        today = str(datetime.datetime.now().date)
        if today in unfinished.keys():
            k = int(input("Enter Task Number : "))
            add = unfinished[today][k]
            add['completion'] = completion
            del unfinished[day][k]
            if len(unfinished) > 0:
                l = len(unfinished)
                finished[l+1] = add
                print("Marked Complete")
            else:
                finished[1] = add
                print("Marked Completer")
        else:
            print("No unfinished tasked for today")
    elif choice == 2:
        if date in unfinished.keys():
            j = int(input('Enter Task Number'))
            if j in unfinished[date].keys():
                add = unfinished[date][j]
                add["completion"] = completion

                del unfinished[date][j]
                if len(unfinished) > 0:
                    l = len(unfinished)
                    finished[l + 1] = add
                    print("Marked Complete")
                else:
                    finished[1] = add
                    print("Marked Complete")

    else:
        print("Invalid Choice")

# %%
def showFinishedTasks(finished):
    # one day all the voices in your head will be gone 
    # because Allah is with those who do sabar,
    # Trust in Allah
    # don't stress yourself with what will happen in Future like I do , In the end Future is very good than your past , It happened to me, live a little
    # 'Your future will be better than your past' Al Quran

    for idx,key in enumerate(finished.keys()):
        idx += 1
        print(f"{idx}  {finished[key]['task']}    {finished[key]['taskAdded']}   {finished[key]['expectedCompletion']}  {finished[key]['completion']}")

# %%
fin = {
    'a':"how are you",
    'b':"What you do"
}

# %%
for idx,key in enumerate(fin):
    print(f"{idx}  {fin[key]}")

# %%
import datetime
import json

# %%
def loadFile(file:str):
        """load any file with this function ,
        parameters:
            file: filename and its extension included should be in form of string 
        Raise:
            FileNotFoundError : when the given file does not exist
        """
        try:
            with open(file,"r") as f:
                data = json.load(f)
        except FileNotFoundError:
            print("FileNotFound")
        return data

def saveFile(file,data):
    with open(file,"w") as f:
        data = json.dumps(data)
        f.write(data)
    print("Saved")

# %%
def showUnfinishedTasks(unfinished):
        print("1. Todays")
        print("2. ALL")

        choice = int(input("Choice : "))
        
        if choice == 1:
            print(f"Index\t Key\tExpected Completion \tTask")
            today = str(datetime.datetime.now().date())
            c = 1
            if len(unfinished[today]) > 0:

                for key in unfinished[today].keys():
                    
                    print(f"{c}\t key[{key}]\t {unfinished[today][key]['expectedCompletion']} \t {unfinished[today][key]['task']}   ")
                    c += 1
            else:
                print("No tasks for today")
        
        elif choice == 2:
            totalLength = 0
            for day in unfinished.keys():
                print(f"Index\t Key\t Day\t Expected Completion \tTask")
                c = 1
                totalLength += len(unfinished[day])
                if len(unfinished[day]) > 0:
                    for key in unfinished[day].keys():
                        print(f"{c} key[{key}] \t {day} {unfinished[day][key]['expectedCompletion']} \t {unfinished[day][key]['task']}   ")
                        c += 1

            
            if totalLength == 0:
                print("No Unfinished Tasks")
        else:
            print("invalid Choice")

# %%
def markTask(finished,unfinished):

        print("~"*20)
        print("1. Mark Todays Task Complete")
        print("2. Enter Day Task Date : ")

        choice = int(input("Choice 1-2 : "))
        print(f"Your Choice : {choice}")

        completion = datetime.datetime.now().strftime("%y-%m-%d, %H:%M")
        if choice == 1:
            showUnfinishedTasks(unfinished)
            today = str(datetime.datetime.now().date())
            if today in unfinished.keys():
                k = input("Enter Task Key Number : ")
                add = unfinished[today][k]
                add['completion'] = completion
                del unfinished[today][k]
                if len(finished) > 0:
                    l = len(finished)
                    finished[l+1] = add
                    print("Marked Complete")
                else:
                    finished[1] = add
                    print("Marked Completer")
            else:
                print("No unfinished tasked for today")
        elif choice == 2:
            showUnfinishedTasks(unfinished)
            date = input("Enter Date format (%yyyy-%mm-%dd)")
            if date in unfinished.keys():
                j = input('Enter Task Number')
                if j in unfinished[date].keys():
                    add = unfinished[date][j]
                    add["completion"] = completion

                    del unfinished[date][j]
                    if len(finished) > 0:
                        l = len(finished)
                        finished[l + 1] = add
                        print("Marked Complete")
                    else:
                        finished[1] = add
                        print("Marked Complete")

        else:
            print("Invalid Choice")

# %%
finished = loadFile("finished.json")
unfinished = loadFile("unfinished.json")

print(finished)
print(unfinished)
# Out:
# {}
# {'2026-06-27': {'1': {'task': 'create UML class and Sequence Diagrams for this project', 'taskAdded': '26y-06-27,22:24', 'expectedCompletion': '2026-07-27'}, '2': {'task': 'write at least 2 blogs on any topic', 'taskAdded': '26y-06-27,22:25', 'expectedCompletion': '2026-07-28'}}}

# %%
markTask(finished,unfinished)
# Out:
# ~~~~~~~~~~~~~~~~~~~~
# 1. Mark Todays Task Complete
# 2. Enter Day Task Date :
# Your Choice : 2
# 1. Todays
# 2. ALL
# 1 key[1] 	 2026-06-27 2026-07-27 	 create UML class and Sequence Diagrams for this project
# 2 key[2] 	 2026-06-27 2026-07-28 	 write at least 2 blogs on any topic
# date 2026-06-27
# here in elif dat is in keys
# j in dates keys
# Marked Complete

# %%
finished
# Out:
# {1: {'task': 'create UML class and Sequence Diagrams for this project',
#   'taskAdded': '26y-06-27,22:24',
#   'expectedCompletion': '2026-07-27',
#   'completion': '26-06-27, 23:33'}}

# %%
def showFinishedTasks(finished):
        # one day all the voices in your head will be gone 
        # because Allah is with those who do sabar,
        # Trust in Allah
        # don't stress yourself with what will happen in Future like I do , In the end Future is very good than your past , It happened to me, live a little
        # 'Your future will be better than your past' Al Quran
        print(f"Index \t Task Added \t\tExpected Completion \tCompletion \t Task")
        for idx,key in enumerate(finished.keys()):
            idx += 1
            print(f"{idx} \t {finished[key]['taskAdded']}\t {finished[key]['expectedCompletion']} \t      {finished[key]['completion']} \t{finished[key]['task']}")

# %%
showFinishedTasks(finished)
# Out:
# Index 	 Task Added 		Expected Completion 	Completion 	 Task
# 1 	 26y-06-27,22:24	 2026-07-27 	      26-06-27, 23:33 	create UML class and Sequence Diagrams for this project
