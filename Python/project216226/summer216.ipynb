# %%
# another project idea an RE search that search for files

# %% [markdown]
# # hostel management system
#
# Functions
# - registers (admin and users)
# - showMenu()
# - roomAvailiability()
# - seating plan()
# - pay fees()
# - track fees and dues()
# - show User Detail
# - do the classes
# - file handling
#
#
# all will be in json

# %%
# create a new student and generate a username and pin for him
# Already created accounts for admin


class Hostel:
    def __init__(self):
        pass

    def
# Out:
#   Cell In[2], line 9
#     def
#        ^
# SyntaxError: invalid syntax

# %%
class hostel:
    def __init__(self):
        pass

    def addHostelite(self,):# for hostelite we will save information and give him a unique id and pin 
        """
            Summary : 
                Add a new hostelite to hostel ,and fill the inputs and this function will generate  a new id  and pin for the hostelite
            it will take inputs like Name, Father Name, Phone, Email, Address, institute

            Parameter:
                accounts : the file that contain the accounts and the new account will be save to that along with the generated UID and password
            
            Error:
                FileNotFound:
                    raised when file is not found and handled by creating a new dictionary that will be saved to create a new file
                ValueError:
                    raised when Invalid data is inputed into input fields
        """

# %%
try:
    name = input("Enter Name : ")
    assert name != "1"
except AssertionError:
    print("Invalid Input")

# %%
# how to make sure that we enter only words not integers 
# one way is to the for loop to check every characters and identify from decimals
# we will have to find another way that is more ok with me

# lets do the first way because I think the second way include search using re
name = input("Nmae ; ")
for char in name:
    if char in "0123456789":
        raise ValueError("No numbers allowed")

# %%
# the above one worked very well now lets go for another round of re
import re
name = input("Name ; ")


pattern = r"\d+"
res = re.findall(pattern,name)
print(res)
if len(res) != 0:
    print("found it ")
else:
    print("all good")
# Out:
# []
# all good

# %%
# first lets create a save and load function and check it in classess if it works
import json
def savefile(filename,extension,data):
    """
    __Summary__:
        This file saves data in given file 
    Parameter:
        filename:
                filename + extension e.g data.json , journel.txt
        data:
                the data you want to save in file
    """
    if extension.lower() == "json":
        with open(f"{filename}.{extension}","w") as f:
            data = json.dumps(data)
            f.write(data)
    else:
        with open(f"{file}.{extension}",'w') as f:
            f.write(data)

def loadfile(filename,extension):
    """
    __Summary__:
        This file load data from given file and store it in variable
    Parameters:
        filename:
            fiel name + its extension
    """
    with open(f"{filename}.{extension}", 'r') as f:
        if extension == "json":
            data = json.load(f)
        else:
            data = f.read()

# %%
import json
class File:
    def __init__(self,):
        pass
    def savefile(filename,extension,data):
        """
        __Summary__:
            This file saves data in given file 
        Parameter:
            filename:
                    filename + extension e.g data.json , journel.txt
            data:
                    the data you want to save in file
        """
        if extension.lower() == "json":
            with open(f"{filename}.{extension}","w") as f:
                data = json.dumps(data)
                f.write(data)
        else:
            with open(f"{filename}.{extension}",'w') as f:
                f.write(data)
        return "File Saved Successfully"

    def loadfile(filename,extension):
        """
        __Summary__:
            This file load data from given file and store it in variable
        Parameters:
            filename:
                fiel name + its extension
        """
        with open(f"{filename}.{extension}", 'r') as f:
            if extension == "json":
                data = json.load(f)
            else:
                data = f.read()
        return data

# %%
c1 = File

# %%
data  = c1.loadfile("borrowedbooks","json")

# %%
data
# Out:
# {'1': {'Book': ['0922108640783',
#    'The Prince',
#    'Niccolo Machiavelli',
#    'Strategy , War, Non Fiction',
#    'Ilam-o-Danish Publication'],
#   'BorrowDate': '2026-06-20 18:16:49.925975',
#   'Borrower': ['Ahmad', 'ahmadktk@gmail.com', 'karak', '8989']},
#  '2': {'Book': ['0922108640783',
#    'The Prince',
#    'Niccolo Machiavelli',
#    'Strategy , War, Non Fiction',
#    'Ilam-o-Danish Publication'],
#   'BorrowDate': '2026-06-20 20:06:06.692903',
#   'Borrower': ['Ahmad', 'ahmadktk@gmail.com', 'karak', '8989']},
#  '3': {'Book': ['0921833269092',
#    'Data Structure Using C++',
#    'CM Aslam , Aqsa Aslam',
#    'Computer Science',
#    'Majeed Sons'],
#   'BorrowDate': '2026-06-20 20:07:18.602933',
#   'Borrower': ['zayan', 'zayanktk@hotmail.com', 'karak', '7890']}}

# %%
data = "Once again another day gone , Today was the day of mind conflics "
c1.savefile("summer21june","txt",data)
# Out:
# 'File Saved Successfully'

# %%
import json
class File:
    def __init__(self,):
        pass
    def savefile(self,filename,extension,data):
        """
        __Summary__:
            This file saves data in given file 
        Parameter:
            filename:
                    filename + extension e.g data.json , journel.txt
            data:
                    the data you want to save in file
        """
        if extension.lower() == "json":
            with open(f"{self.filename}.{self.extension}","w") as f:
                data = json.dumps(self.data)
                f.write(data)
        else:
            with open(f"{self.filename}.{self.extension}",'w') as f:
                f.write(data)
        return "File Saved Successfully"

    def loadfile(self,filename,extension):
        """
        __Summary__:
            This file load data from given file and store it in variable
        Parameters:
            filename:
                fiel name + its extension
        """
        with open(f"{self.filename}.{self.extension}", 'r') as f:
            if extension == "json":
                data = json.load(f)
            else:
                data = f.read()
        return data

# %%
name = input("Name ")
try:
    first,last = name.split(" ")
except ValueError:
    first = name

print(first)

# I would say this is my best ever exception handling with me thinking from brain

# %%
name = "Ahmad"

first,last = name.split(" ")

print(type(first)) # all good now lets go to the second part

phone = "03109945689"
print(phone[-3:]) # all right giggity
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 name = "Ahmad"
#       2
# ----> 3 first,last = name.split(" ")
#       4
#       5 print(type(first)) # all good now lets go to the second part
#       6
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
# I want to check the error if I raise one how can i except it 
import re
try:
    name = input("Nmae ; ")
    fname = input("Father Name : ")
    res = re.findall(r"\d+",data)
    print(res)
    if len(res) == 0:
        print("all goood")
    else:
        raise ValueError
except ValueError:
    print("use only alphabets")

# yes it did works but we have to do each individually 
# so by that way I prefer the for loop thng
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 12
#       8     if len(res) == 0:
#       9         print("all goood")
#      10     else:
#      11         raise ValueError
# ---> 12 except ValueError:
#      13     print("use only alphabets")
#      14
#      15 # yes it did works but we have to do each individually
#
# File c:\Users\Khattak\.conda\envs\myenv\Lib\re\__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)    214
#     215     Empty matches are included in the result."""
# --> 216     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object, got 'dict'

# %%
try:
    name = input("Nmae ; ")
    fname = input("Father Name : ")
    no = "0123456789"
    for char in name,fname:
        if char in no:
            raise ValueError
except ValueError:
    print("use only alphabets")

# we have to do it individually too 
# another way is to make a long string of all the string variables and save it to one variable then do the exception handling on it
# Out:
# use only alphabets

# %%
import json
class File:
    def __init__(self,):
        pass
    def savefile(filename,extension,data):
        """
        __Summary__:
            This file saves data in given file 
        Parameter:
            filename:
                    filename + extension e.g data.json , journel.txt
            data:
                    the data you want to save in file
        """
        if extension.lower() == "json":
            with open(f"{filename}.{extension}","w") as f:
                data = json.dumps(data)
                f.write(data)
        else:
            with open(f"{filename}.{extension}",'w') as f:
                f.write(data)
        return "File Saved Successfully"

    def loadfile(filename,extension):
        """
        __Summary__:
            This file load data from given file and store it in variable
        Parameters:
            filename:
                fiel name + its extension
        """
        with open(f"{filename}.{extension}", 'r') as f:
            if extension == "json":
                data = json.load(f)
            else:
                data = f.read()
        return data

# %%
import random
def hostelite(hostelers,accounts):
    name = input("Name : ")
    fname = input("Father Name : ")
    phone = input("Phone Number: ")
    mail = input("Email Address : ")
    student = True
    student = input("True/ False").capitalize()
    institute = input("Institute Name : ")

    # we will implement the exception handling thing but letter
    # for now lets focus on generating the username and pin for a user 
    # username = firstname + last 3 digits of phone 
    # pin randomly generated 5 digits

    
    UID = accounts.keys()
    UID = len(UID)
    UID = UID + 1


    # creating a username 
    try:
        first,last = name.split(" ")
    except ValueError:
        first = name
    
    username = first+phone[-3:]
    pin = random.randint(11111,99999)

    user = {
        "UserDetails":[name,fname,phone,student,institute],
        "Account":[username,pin]
    }

    accounts[UID] = [username,pin]
    hostelers[UID] = user

# %%
c2 = File
hostelites = c2.loadfile("hostelites","json")
accounts = c2.loadfile('accounts',"json")

# %%
hostelite(hostelites,accounts)

c2.savefile("hostelites",'json',hostelites)
c2.savefile("accounts",'json',accounts)
# Out:
# 'File Saved Successfully'

# %%
# now what I have to find a way to extract the name and UID for the given user

# room 1 { 1 : [1:"Ahmad"],
# }

# I think I will get both details fromt the 

# I think less details would be good

for item in hostelites.items():
    print(item[0][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       7
#       8 # I think less details would be good
#       9
#      10 for item in hostelites.items():
# ---> 11     print(item[0][1])
#
# TypeError: 'int' object is not subscriptable

# %%
items = hostelites.items()
print(items)
# print(items[0]["UserDetials"])

items = list(items)
print(items)

print(items[0][1])
print(items[2][1]["UserDetails"][0])
# how to we find the person Id using his
# Out:
# dict_items([('1', {'UserDetails': ['zayan', 'aslam', '233535135', 'True', 'case isb'], 'Account': ['zayan135', 12404]}), ('2', {'UserDetails': ['Ahmad', '', '', '', ''], 'Account': ['Ahmad', 97732]}), (3, {'UserDetails': ['Ahmad', 'Ibrahim', '03499078300', 'True', 'CASE Islamabad'], 'Account': ['Ahmad300', 46826]}), (4, {'UserDetails': ['Zayan', 'Aslam', '03458967333', 'False', 'Not a student'], 'Account': ['Zayan333', 75919]}), (5, {'UserDetails': ['Ali Dayan', 'haji', '03452425289', 'True', 'CASE Institute'], 'Account': ['Ali289', 35944]})])
# ...

# %%
name = input("Name : ")
item = list(hostelites.items())

for i in item:
    j = 0
    print(i)
    if name == i[f"{j}"]["UserDetails"][0]:
        print(i[f"{j}"])
# Out:
# ('1', {'UserDetails': ['zayan', 'aslam', '233535135', 'True', 'case isb'], 'Account': ['zayan135', 12404]})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 7
#       3
#       4 for i in item:
#       5     j = 0
#       6     print(i)
# ----> 7     if name == i[f"{j}"]["UserDetails"][0]:
#       8         print(i[f"{j}"])
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# show the room details
# this function will show the assigned user to the rooms 
# we will perform the operations like show the rooms, and add a new student to the class and remove a student 
# only admin will do this 
# what we will do is that show the room details in a good print format

rooms = 
def roomAllocation(rooms:dict):
    # now first thing is to show the rooms allocation
    # what we will show is the name of person and his assigned UID in hostelers

# %%
c2 = File

c2.loadfile

# %%
import random
import json
class Hostel:
    def __init__(self,):
        pass

    def savefile(filename,extension,data):
        """
        __Summary__:
            This file saves data in given file 
        Parameter:
            filename:
                    filename + extension e.g data.json , journel.txt
            data:
                    the data you want to save in file
        """
        if extension.lower() == "json":
            with open(f"{filename}.{extension}","w") as f:
                data = json.dumps(data)
                f.write(data)
        else:
            with open(f"{filename}.{extension}",'w') as f:
                f.write(data)
        return "File Saved Successfully"

    def loadfile(filename,extension):
        """
        __Summary__:
            This file load data from given file and store it in variable
        Parameters:
            filename:
                fiel name + its extension
        """
        with open(f"{filename}.{extension}", 'r') as f:
            if extension == "json":
                data = json.load(f)
            else:
                data = f.read()
        return data
    def hostelite(hostelers,accounts):
        name = input("Name : ")
        fname = input("Father Name : ")
        phone = input("Phone Number: ")
        mail = input("Email Address : ")
        student = True
        student = input("True/ False").capitalize()
        institute = input("Institute Name : ")
    
        # we will implement the exception handling thing but letter
        # for now lets focus on generating the username and pin for a user 
        # username = firstname + last 3 digits of phone 
        # pin randomly generated 5 digits
    
        
        UID = accounts.keys()
        UID = len(UID)
        UID = UID + 1
    
    
        # creating a username 
        try:
            first,last = name.split(" ")
        except ValueError:
            first = name
        
        username = first+phone[-3:]
        pin = random.randint(11111,99999)
    
        user = {
            "UserDetails":[name,fname,phone,student,institute],
            "Account":[username,pin]
        }
    
        accounts[UID] = [username,pin]
        hostelers[UID] = user

# %%
menu = {
    "Monday": {
        "Breakfast": "Paratha Chai",
        "Noon": "Mix Sabzi",
        "Dinner":"Alo Ghost"
    },
    "Tuesday":{
        "Breakfast": "Paratha Chai",
        "Noon":"Daal",
        "Dinner":"Mix Chawal"
    },
    "Wednesday":{
        "Breakfast": "Bread Jam",
        "Noon":"Lobia",
        "Dinner":"Microni"
    },
    "Thursday":{
        "Breakfast": "Paratha Chai",
        "Noon":"Sabzi",
        "Dinner":"Kabali Palow"
    },
    "Friday":{
        "Breakfast": "Bread Jam",
        "Noon":"Lobia",
        "Dinner":"Kaleji"
    },
    "Saturday":{
        "Breakfast": "Paratha Chai",
        "Noon":"Cholay",
        "Dinner":"Biryani"
    },
    "Sunday":{
        "Breakfast": "Paratha Anda Chai",
        "Noon":"Alo",
        "Dinner":"Ghost"
    },
}

c1 = Hostel
c1.savefile("Menu","json",menu)
# Out:
# 'File Saved Successfully'

# %%
for i in menu.items():
    print(type(i))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
for i in menu.items():
    print(i)
# Out:
# ('Monday', {'Breakfast': 'Paratha Chai', 'Noon': 'Mix Sabzi', 'Dinner': 'Alo Ghost'})
# ('Tuesday', {'Breakfast': 'Paratha Chai', 'Noon': 'Daal', 'Dinner': 'Mix Chawal'})
# ('Wednesday', {'Breakfast': 'Bread Jam', 'Noon': 'Lobia', 'Dinner': 'Microni'})
# ('Thursday', {'Breakfast': 'Paratha Chai', 'Noon': 'Sabzi', 'Dinner': 'Kabali Palow'})
# ('Friday', {'Breakfast': 'Bread Jam', 'Noon': 'Lobia', 'Dinner': 'Kaleji'})
# ('Saturday', {'Breakfast': 'Paratha Chai', 'Noon': 'Cholay', 'Dinner': 'Biryani'})
# ('Sunday', {'Breakfast': 'Paratha Anda Chai', 'Noon': 'Alo', 'Dinner': 'Ghost'})

# %%
for i in menu.keys():
    for j in menu[i].keys():
        print(f"")
# Out:
#   Cell In[17], line 1
#     for i in menu.keys():
#                          ^
# _IncompleteInputError: incomplete input

# %%
for i in menu.keys():
    for j in menu[i].keys():
        print(menu[i][j])

    print("\n")
# Out:
# Paratha Chai
# Mix Sabzi
# Alo Ghost
#
#
# Paratha Chai
# Daal
# Mix Chawal
#
#
# Bread Jam
# Lobia
# Microni
#
#
# Paratha Chai
# Sabzi
# Kabali Palow
#
#
# Bread Jam
# Lobia
# Kaleji
#
#
# Paratha Chai
# Cholay
# Biryani
#
#
# Paratha Anda Chai
# Alo
# Ghost

# %%
tup = ("Ahmad",23)
print(tup[1])
print(type(tup))
# Out:
# 23
# <class 'tuple'>

# %%
for item in menu.items():
        print(f"{item[0]} {item[1][0]} {item[1][1]} {item[1][2]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 for item in menu.items():
# ----> 2         print(f"{item[0]} {item[1][0]} {item[1][1]} {item[1][2]}")
#
# KeyError: 0

# %%
menu = {
    "Monday": {
        "Breakfast": "Paratha Chai",
        "Noon": "Mix Sabzi",
        "Dinner":"Alo Ghost"
    },
    "Tuesday":{
        "Breakfast": "Paratha Chai",
        "Noon":"Daal",
        "Dinner":"Mix Chawal"
    },
    "Wednesday":{
        "Breakfast": "Bread Jam",
        "Noon":"Lobia",
        "Dinner":"Microni"
    },
    "Thursday":{
        "Breakfast": "Paratha Chai",
        "Noon":"Sabzi",
        "Dinner":"Kabali Palow"
    },
    "Friday":{
        "Breakfast": "Bread Jam",
        "Noon":"Lobia",
        "Dinner":"Kaleji"
    },
    "Saturday":{
        "Breakfast": "Paratha Chai",
        "Noon":"Cholay",
        "Dinner":"Biryani"
    },
    "Sunday":{
        "Breakfast": "Paratha Anda Chai",
        "Noon":"Alo",
        "Dinner":"Ghost"
    },
}

# c1 = Hostel
# c1.savefile("Menu","json",menu)

# %%
print(menu)
# Out:
# {'Monday': {'Breakfast': 'Paratha Chai', 'Noon': 'Mix Sabzi', 'Dinner': 'Alo Ghost'}, 'Tuesday': {'Breakfast': 'Paratha Chai', 'Noon': 'Daal', 'Dinner': 'Mix Chawal'}, 'Wednesday': {'Breakfast': 'Bread Jam', 'Noon': 'Lobia', 'Dinner': 'Microni'}, 'Thursday': {'Breakfast': 'Paratha Chai', 'Noon': 'Sabzi', 'Dinner': 'Kabali Palow'}, 'Friday': {'Breakfast': 'Bread Jam', 'Noon': 'Lobia', 'Dinner': 'Kaleji'}, 'Saturday': {'Breakfast': 'Paratha Chai', 'Noon': 'Cholay', 'Dinner': 'Biryani'}, 'Sunday': {'Breakfast': 'Paratha Anda Chai', 'Noon': 'Alo', 'Dinner': 'Ghost'}}

# %%
def showMenu(menu:dict):
    # this function will show the weekly Menu which will be stored in Menu.json
    print(f"Day \t\t Breakfast \t\t Afternoon\t\t Dinner")
    # keyys = []
    for i in menu.keys():
        # for j in menu[i].key():
        #     keyys.append(i)
        print(f"{i}>---------<{menu[i]['Breakfast']}>---------<{menu[i]['Noon']}>---------<{menu[i]['Dinner']} ")

# %%
showMenu(menu)
# Out:
# Day 		 Breakfast 		 Afternoon		 Dinner
# Monday>---------<Paratha Chai>---------<Mix Sabzi>---------<Alo Ghost
# Tuesday>---------<Paratha Chai>---------<Daal>---------<Mix Chawal
# Wednesday>---------<Bread Jam>---------<Lobia>---------<Microni
# Thursday>---------<Paratha Chai>---------<Sabzi>---------<Kabali Palow
# Friday>---------<Bread Jam>---------<Lobia>---------<Kaleji
# Saturday>---------<Paratha Chai>---------<Cholay>---------<Biryani
# Sunday>---------<Paratha Anda Chai>---------<Alo>---------<Ghost

# %%
d1 = Hostel

hostelers = d1.loadfile("hostelites","json")
accounts = d1.loadfile("accounts","json")


print(hostelers)
print(accounts)
# Out:
# {'1': {'UserDetails': ['zayan', 'aslam', '233535135', 'True', 'case isb'], 'Account': ['zayan135', 12404]}, '2': {'UserDetails': ['Ahmad', '', '', '', ''], 'Account': ['Ahmad', 97732]}, '3': {'UserDetails': ['Ahmad', 'Ibrahim', '03499078300', 'True', 'CASE Islamabad'], 'Account': ['Ahmad300', 46826]}, '4': {'UserDetails': ['Zayan', 'Aslam', '03458967333', 'False', 'Not a student'], 'Account': ['Zayan333', 75919]}, '5': {'UserDetails': ['Ali Dayan', 'haji', '03452425289', 'True', 'CASE Institute'], 'Account': ['Ali289', 35944]}, '6': {'UserDetails': ['', '', '', '', ''], 'Account': ['', 13697]}}
# {'1': ['zayan135', 12404], '2': ['Ahmad', 97732], '3': ['Ahmad300', 46826], '4': ['Zayan333', 75919], '5': ['Ali289', 35944], '6': ['ktk', 13697]}

# %% [markdown]
# format for room allocation is to be
# rooms = {
# room1:{
# 1:['Ahmad','03407878345'],
# 2:["ktk",'2324254252'],
# }
# }

# %%
def initializeRooms():
    rooms = {}
    for i in range(17):
        kamra=  {}
        
        for j in range(4):
            kamra[j+1] = ["",""]
    
        rooms[f"room{i+1}"] = kamra

    return rooms

rooms = initializeRooms()
print(rooms)
# Out:
# {'room1': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room2': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room3': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room4': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room5': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room6': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room7': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room8': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room9': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room10': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room11': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room12': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room13': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room14': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room15': {1: ['', ''], 2: ['', ''], 3: ['', ''], 4: ['', '']}, 'room16': {1: ['', ''], 2: ['', ''], 3: ['', '
# ...

# %%
roomsSeating = d1.loadfile("roomsSeating",'json')

# %%
# creating a room allocation and room seating function

# this will contain the name and room of the person and His mail Id

# how we will do it lets us see
# this function will first lets us see all the rooms seating then If we want to change it

def showSeating(roomSeating):
    for key in roomSeating.keys():
        for seat in roomSeating[key].keys():
            print(f"{key}\t Seat {seat} Name  {roomSeating[key][seat][0]}  Phone {roomSeating[key][seat][1]}  ")
def allocateRoom(rooms):
    name = input("Name : ").capitalize()
    phone = input("Phone : ")
    room = input("room: format(room1,room5) : ").lower()
    avail = []
    for key in rooms[room].keys():
        
        if len(rooms[room][key][0]) == 0:
            avail.append(key)
    
    if len(avail) == 0:
        raise ValueError(f"{room} is full")
    else:
        for i in avail:
            rooms[room][i] = [name,phone]
            print(f"{name} is allocated to {room} seat {i}  ")
            break


def deallocateRoom(rooms):
    name = input("name : ").capitalize()
    room = input("room1 : ").lower()
    found = False
    for seat in rooms[room].keys():
        if name == rooms[room][seat][0]:
            found = True
            rooms[room][seat] = ["",""]
    
    if not found:
        return f"{name} not found"
    else:
        return f"Successfully de allocated the seat"
    

def roomAllocation(roomSeating,hostelers):
    # the function should Initialy show the rooms seating and then ask user to update
    # I think I have to ask user to choose what todo and use while loop
    # if there is already a hosteler it shall raise an error
    while True:
        print("1. See Rooms Seating")
        print("2. Allocate New Hosteler to Room")
        print("3. Deallocate Hosteller Room")
        print("4. Finish Room Allocation Menu")
        choice = int(input("Enter Choice : "))

        if choice == 1:
            showSeating(roomsSeating)
        elif choice == 2:
            # there is a way to show which rooms are availble but this will the code lengthy
            # simple entry 
            allocateRoom(RoomsSeating)
        elif choice == 3:
            deallocateRoom(RoomsSeating)
        else:
            print("Exiting Room Allocation Menu . . .")
            break

# %%
# this will the last day of the project I have been late by 3 days it should be finished by 22 june by It did not today is 25  june

# creating a function for track fees
# this will contain a person name, his room and paid and unpaid status

# %% [markdown]
#  the feeRecord
#
#  record = {
#     'january':{
#      paid = ["name",'name2',],
#      unpaid = ['name3',"name4"]
#     },
#     "febrary"
#  }

# %%
# now what I have to do is create a way to initialize the fee record
import datetime
feeRecord = {}

now = datetime.datetime.now().date()
now
print(now)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 6
#       3 feeRecord = {}
#       5 now = datetime.datetime.now().date()
# ----> 6 now.month()
#       7 print(now)
#
# TypeError: 'int' object is not callable

# %%
freeRecord = {
    "paid":{

    },
    "unpaid":{

    }
}

# lets create some logic

# first we will add every person to unpaid and then we will change its status by payfees

hostelites

# %%
# Now toward the last function which is tracks and pay fees
# the track fees function which will track who is paid and unpaid from the hostelites ( initially I inputed the paid and upaid status hostelites but I think I shall remove it from there and use it here)

def trackFees(feeRecord):
    # the fees record shall be shown by unpaid and paid {
    # [name,'room']
    # }
